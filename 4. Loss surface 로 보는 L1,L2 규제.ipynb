# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.rc('font', family = 'malgun gothic')
plt.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# ### 예제 데이터 생성

# %%
x1 = np.linspace(0,10,100).reshape(-1,1)
x2 = np.linspace(0,10,100).reshape(-1,1)

X = np.array([x1,x2])

error = (np.random.randn(100) * 50).reshape(-1,1)

weights = np.array([5.2,7.5]).reshape(-1,1)

Y = X[0]*weights[0] + X[1]*weights[1] + error # 가중치가  두 개인 예제 회귀 모형 생성 
Y = Y.reshape(-1,1)

# %%
def make_3dplot(x,y,z):
    
    
    fig = plt.figure(figsize = (5,5))
    ax = fig.add_subplot(projection = '3d')


    ax.scatter(x,y,z)
    ax.set_xlabel('x1')
    ax.set_ylabel('x2')
    ax.set_zlabel('Y')


        
    return ax

# %%
ax = make_3dplot(X[0],X[1],Y)
ax.set_title('실제값의 산점도')
# Out:
# Text(0.5, 0.92, '실제값의 산점도')

# %% [markdown]
# # 규제가 없는 경우의 Loss Surface

# %%
def loss_function(y,predicted):
    
    
    MSE = np.mean((y - predicted)**2)
    
    return MSE

# %%
# 가중치 범위 설정

w1_list = np.linspace(-10, 30, 100)
w2_list = np.linspace(-10, 30, 100)

# 손실 함수 계산
losses = np.zeros((100, 100))
for i, w1 in enumerate(w1_list):
    for j, w2 in enumerate(w2_list):
        predicted = x1 * w1 + x2 * w2
        losses[i, j] = loss_function(Y, predicted.reshape(-1, 1))
        
w1_list, w2_list = np.meshgrid(w1_list, w2_list)

# %%
def make_3d_surface(x,y,z,c):
    
    fig,ax = plt.subplots(ncols = 3, subplot_kw = {'projection':'3d'},
                            figsize = (20,5))
    
        
    ax[0].plot_surface(x,y,z,
                    cmap = c)
    ax[0].set_xlabel('W1')
    ax[0].set_ylabel('W2')
    ax[0].set_zlabel('Loss')
    ax[0].view_init(10,15)
        
    ax[1].plot_surface(x,y,z,
                    cmap = c)
    ax[1].set_xlabel('W1')
    ax[1].set_ylabel('W2')
    ax[1].set_zticks([])
    ax[1].set_zlabel('Loss')
    ax[1].view_init(90,30)
    
    ax[2].plot_surface(x,y,z,
                    cmap = c)
    ax[2].set_xlabel('W1')
    ax[2].set_ylabel('W2')
    ax[2].set_zlabel('Loss')
    ax[2].view_init(10,90)
        

    
    return fig,ax

# %%
fig , ax = make_3d_surface(w1_list,w2_list,losses,'Blues_r')

fig.suptitle('규제가 없는 Loss surface')
# Out:
# Text(0.5, 0.98, '규제가 없는 Loss surface')

# %% [markdown]
# # L2 규제량에 따른 Loss surface 의 변화를 보자
#
# * $L_{reg} = L + \lambda\sum_{j=1}^{n}{w_j^2}$
#
# # L2 규제
#
# * L2 규제는 3차원 loss surface에서 파라미터 공간의 크기를 제한하여 일반화 성능을 높이는 효과가 있습니다. 3차원 공간에서 파라미터 w1, w2, loss 값을 각각 x, y, z축으로 나타낼 수 있습니다.
#
# * 만약 L2 규제가 적용되지 않은 경우, loss surface는 규제가 없는 매끄러운 곡면으로 나타납니다. 이 경우 파라미터 공간에서 어디에서나 손실 함수를 최적화할 수 있는 포인트가 있습니다. 그러나 이렇게 학습한 모델은 새로운 데이터에서 성능이 좋지 않을 수 있습니다.
#
# * 반면에 L2 규제를 적용하면, loss surface는 구부러진 형태를 가지게 됩니다. L2 규제는 파라미터 w1, w2의 크기에 대한 제한을 가하는데, 이로 인해 파라미터 공간의 크기가 작아집니다. 이는 일종의 "파라미터의 수용력(capacity)"을 줄이는 효과가 있습니다. 이러한 규제는 loss surface에서 전체적으로 규제가 생기게 됩니다. 그 결과, 규제가 없는 loss surface보다 최적화되기 더 어려운 포인트가 존재합니다. 따라서 모델은 더 많은 데이터에 일반화되는 경향이 있습니다.
#
# * 결론적으로, L2 규제는 3차원 loss surface에서 파라미터 공간의 크기를 제한하여 모델의 일반화 성능을 높이는 효과가 있습니다

# %%
def L2_loss_function(X,Y,weights,alpha):
    
    m = len(X)
    
    predicted = X.T @ weights
    
    base_loss = loss_function(Y,predicted)
    
    ridge = alpha * np.sqrt(weights[0] ** 2 + weights[1] **2)
        
    return base_loss + ridge

# %%
# 가중치 범위 설정

w1_list = np.linspace(-10, 30, 100)
w2_list = np.linspace(-10, 30, 100)


alphas = [0,1e+3,1e+5,1e+10]

# 손실 함수 계산

losses_list = []
for alpha in alphas:
    losses = np.zeros((100, 100))
    for i, w1 in enumerate(w1_list):
        for j, w2 in enumerate(w2_list):
            
            new_weights = np.array([w1,w2]).reshape(-1,1)
            predicted = X[0]*new_weights[0] + X[1]*new_weights[1]
            
            losses[i, j] = L2_loss_function(X,Y, new_weights,alpha)
        
    losses_list.append(losses)
    
w1_list, w2_list = np.meshgrid(w1_list, w2_list)

# %%
def make_multiple_3d_surface(x,y,z_list):
    
    fig,ax = plt.subplots(ncols = 3, subplot_kw = {'projection':'3d'},
                            figsize = (20,5))
    
    colors = ['Blues_r','winter','summer','spring']
    
    alphas = [0,1e+3,1e+5,1e+10]

    
    for i,z in enumerate(z_list):
        
        z = np.log10(z) # 한 평면상에 표현하기 위해 Loss 값에 log 를 취해주었다.
        
        ax[0].plot_surface(x,y,z,
                        cmap = colors[i],
                        label = alphas[i])
        ax[0].set_xlabel('W1')
        ax[0].set_ylabel('W2')
        ax[0].set_zlabel('Loss')
        ax[0].view_init(10,15)
            
        ax[1].plot_surface(x,y,z,
                        cmap = colors[i],
                        label = alphas[i])
        ax[1].set_xlabel('W1')
        ax[1].set_ylabel('W2')
        ax[1].set_zlabel('Loss')
        ax[1].view_init(45,30)
        
        ax[2].plot_surface(x,y,z,
                        cmap = colors[i],
                        label = alphas[i])
        ax[2].set_xlabel('W1')
        ax[2].set_ylabel('W2')
        ax[2].set_zlabel('Loss')
        ax[2].view_init(10,90)
    
    return fig,ax

# %%
fig,ax = make_multiple_3d_surface(w1_list,w2_list,losses_list)
fig.suptitle('규제 정도에 따른 Loss surface 의 변화')
# Out:
# Text(0.5, 0.98, '규제 정도에 따른 Loss surface 의 변화')

# %% [markdown]
# ### 규제 값이 올라 갈 수록 Loss surface 의 모양이 단순해지고 있음을 볼 수 있습니다.
# * 이는 가중치들이 가질 수 있는 값의 영여이 축소 됨에 따라 loss surface 의 모양이 단순해집니다.
# * 또 Train set 의 global minimum 의 기준과 다르기에 각 규제값에 따른 최적의 가중치 값은 Train set 의 Loss surface Global minimum에 위치하지는 않습니다.
# * 하지만 Global minimun 에서는 크게 벗어나지 않습니다
#
# ### 즉, 규제란 가중치가 가질 수 있는 값의 영역을 제한하여 복잡한 Loss surface를 비교적 단순하게 만들어 Train set의 Loss surface에 과적합 되지 않도록 하여 일반화 성능을 높힙니다.

# %% [markdown]
# # L1 규제
#
# $L_{reg} = L + \lambda\sum_{j=1}^{n}{\left|w_j\right|}$
#
# * 여기서 λ는 규제의 강도를 조절하는 하이퍼파라미터이며, w는 모델의 가중치입니다. L1 규제는 L2 규제와 마찬가지로 가중치의 크기가 커질수록 규제 항의 값이 증가하여 모델이 복잡해지는 것을 방지합니다.
#
#  * L1 규제는 L2 규제와 달리 가중치의 절댓값에 대한 항이 포함되어 있으므로, 가중치가 0에 가까워지는 효과가 더 크게 나타납니다. 따라서 L1 규제는 희소성(sparcity)을 강조하는 효과가 있어, 모델이 불필요한 특성(feature)을 제거하고 더 간결한 형태로 학습되도록 도와줍니다.
#
#  * L1 규제의 적용으로 인해 Loss surface 또한 L2 규제의 경우와 마찬가지로 더 단순한 모양으로 변화합니다. 따라서 일반화 성능을 높이는 효과가 있습니다.

# %%
def L1_loss_function(X,Y,weights,alpha):
    
    m = len(X)
    
    predicted = X.T @ weights
    
    base_loss = loss_function(Y,predicted)
    
    lasso = alpha * np.abs(weights[0] + weights[1])
        
    return base_loss + lasso

# %%
# 가중치 범위 설정

w1_list = np.linspace(-10, 30, 100)
w2_list = np.linspace(-10, 30, 100)


alphas = [0,1e+3,1e+5,1e+10]

# 손실 함수 계산

losses_list = []
for alpha in alphas:
    losses = np.zeros((100, 100))
    for i, w1 in enumerate(w1_list):
        for j, w2 in enumerate(w2_list):
            
            new_weights = np.array([w1,w2]).reshape(-1,1)
            predicted = X[0]*new_weights[0] + X[1]*new_weights[1]
            
            losses[i, j] = L2_loss_function(X,Y, new_weights,alpha)
        
    losses_list.append(losses)
    
w1_list, w2_list = np.meshgrid(w1_list, w2_list)

# %%
fig,ax = make_multiple_3d_surface(w1_list,w2_list,losses_list)
fig.suptitle('L1 규제 정도에 따른 Loss surface 의 변화')
# Out:
# Text(0.5, 0.98, 'L1 규제 정도에 따른 Loss surface 의 변화')
